# %%
import numpy as np 
import pandas as pd

import matplotlib.pyplot as plt 
import seaborn as sns

# %matplotlib inline

# %%
df_miles = pd.read_csv("miles_selected.dat")

# %%
df_miles.head
# Out:
# <bound method NDFrame.head of      Miles          Name  Teff  [Fe/H]  logg
# 0        1     HD 224930  5411   -0.78  4.19
# 1        2     HD 225212  4179    0.18  0.85
# 2        3     HD 225239  5559   -0.51  3.72
# 3        4      HD 00004  6779    0.21  3.87
# 4        5      HD 00249  4766   -0.27  2.91
# ..     ...           ...   ...     ...   ...
# 974    981  NGC 7789 765  4333   -0.13  1.91
# 975    982  NGC 7789 859  4579   -0.13  2.26
# 976    983  NGC 7789 875  4861   -0.13  2.56
# 977    984  NGC 7789 897  4918   -0.13  2.50
# 978    985  NGC 7789 971  3737   -0.13  1.20
#
# [979 rows x 5 columns]>

# %%
df_miles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 979 entries, 0 to 978
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Miles   979 non-null    int64
#  1   Name    979 non-null    object
#  2   Teff    979 non-null    int64
#  3   [Fe/H]  979 non-null    float64
#  4   logg    979 non-null    float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 38.4+ KB

# %%
df_miles.describe()
# Out:
#             Miles          Teff      [Fe/H]        logg
# count  979.000000    979.000000  979.000000  979.000000
# mean   491.638407   6193.312564   -0.346190    3.103136
# std    284.523589   3333.199309    0.628538    1.217393
# min      1.000000   3160.000000   -3.150000    0.170000
# 25%    245.500000   4624.000000   -0.625000    2.210000
# 50%    491.000000   5329.000000   -0.140000    3.630000
# 75%    736.500000   6396.000000    0.080000    4.130000
# max    985.000000  35500.000000    1.000000    5.700000

# %%
array = np.load("MILES_spectra.npz")

# %%
len(array)
# Out:
# 2

# %%
array["star_name"]
# Out:
# array(['Untitled0.ipynb', 's0021.fits', 's0041.fits', 's0047.fits',
#        's0032.fits', 's0038.fits', 's0022.fits', 's0019.fits',
#        's0042.fits', 's0037.fits', 's0023.fits', 's0045.fits',
#        's0009.fits', 's0036.fits', 's0029.fits', 's0031.fits',
#        's0034.fits', 's0040.fits', 's0035.fits', 's0008.fits',
#        's0015.fits', 's0012.fits', 's0010.fits', 's0028.fits',
#        's0039.fits', 's0018.fits', 's0043.fits', 's0013.fits',
#        's0026.fits', 's0024.fits', 's0044.fits', 's0027.fits',
#        's0048.fits', 's0030.fits', 's0003.fits', 's0016.fits',
#        's0005.fits', 's0004.fits', 's0007.fits', 's0011.fits',
#        's0001.fits', 's0033.fits', 's0002.fits', 's0049.fits',
#        's0014.fits', 's0025.fits', 's0020.fits', 's0006.fits',
#        's0046.fits', 's0017.fits', 's0061.fits', 's0074.fits',
#        's0093.fits', 's0089.fits', 's0062.fits', 's0052.fits',
#        's0105.fits', 's0119.fits', 's0076.fits', 's0075.fits',
#        's0118.fits', 's0139.fits', 's0137.fits', 's0055.fits',
#        's0098.fits', 's0123.fits', 's0087.fits', 's0058.fits',
#        's0059.fits', 's0109.fits', 's0096.fits', 's0126.fits',
#        's0128.fits', 's0106.fits', 's0136.fits', 's0054.fits',
#        's0084.fits', 's0104.fits', 's0060.fits', 's0080.fits',
#        's0120.fits', 's0086.fits', 's0095.fits', 's0072.fits',
#        's0053.fits', 's0091.fits', 's0057.fits', 's0077.fits',
#        's0092.fits', 's0116.fits', 's0133.fits', 's0101.fits',
#        's0079.fits', 's0069.fits', 's0063.fits', 's0113.fits',
#        's0107.fits', 's0134.fits', 's0100.fits', 's0125.fits',
#        's0073.fits', 's0114.fits', 's0127.fits', 's0131.fits',
#        's0051.fits', 's0067.fits', 's0103.fits', 's0108.fits',
#        's0110.fits', 's0056.fits', 's0066.fits', 's0130.fits',
#        's0094.fits', 's0068.fits', 's0117.fits', 's0081.fits',
#        's0088.fits', 's0122.fits', 's0142.fits', 's0129.fits',
#        's0065.fits', 's0082.fits', 's0102.fits', 's0083.fits',
#        's0112.fits', 's0099.fits', 's0121.fits', 's0141.fits',
#        's0064.fits', 's0097.fits', 's0071.fits', 's0111.fits',
#        's0078.fits', 's0090.fits', 's0138.fits', 's0070.fits',
#        's0050.fits', 's0140.fits', 's0135.fits', 's0132.fits',
#        's0124.fits', 's0115.fits', 's0085.fits', 's0206.fits',
#        's0218.fits', 's0211.fits', 's0154.fits', 's0249.fits',
#        's0227.fits', 's0160.fits', 's0194.fits', 's0162.fits',
#        's0148.fits', 's0239.fits', 's0161.fits', 's0156.fits',
#        's0151.fits', 's0226.fits', 's0171.fits', 's0185.fits',
#        's0243.fits', 's0247.fits', 's0229.fits', 's0232.fits',
#        's0153.fits', 's0248.fits', 's0163.fits', 's0242.fits',
#        's0170.fits', 's0181.fits', 's0230.fits', 's0150.fits',
#        's0166.fits', 's0213.fits', 's0177.fits', 's0143.fits',
#        's0241.fits', 's0200.fits', 's0173.fits', 's0225.fits',
#        's0152.fits', 's0145.fits', 's0190.fits', 's0159.fits',
#        's0216.fits', 's0189.fits', 's0251.fits', 's0215.fits',
#        's0220.fits', 's0158.fits', 's0157.fits', 's0168.fits',
#        's0205.fits', 's0169.fits', 's0231.fits', 's0208.fits',
#        's0187.fits', 's0207.fits', 's0219.fits', 's0237.fits',
#        's0195.fits', 's0197.fits', 's0199.fits', 's0191.fits',
#        's0221.fits', 's0182.fits', 's0196.fits', 's0214.fits',
#        's0164.fits', 's0236.fits', 's0224.fits', 's0192.fits',
#        's0234.fits', 's0244.fits', 's0144.fits', 's0209.fits',
#        's0212.fits', 's0149.fits', 's0172.fits', 's0167.fits',
#        's0217.fits', 's0203.fits', 's0179.fits', 's0233.fits',
#        's0165.fits', 's0175.fits', 's0210.fits', 's0184.fits',
#        's0235.fits', 's0222.fits', 's0246.fits', 's0147.fits',
#        's0240.fits', 's0228.fits', 's0183.fits', 's0146.fits',
#        's0198.fits', 's0245.fits', 's0250.fits', 's0201.fits',
#        's0174.fits', 's0180.fits', 's0202.fits', 's0223.fits',
#        's0238.fits', 's0188.fits', 's0186.fits', 's0193.fits',
#        's0204.fits', 's0178.fits', 's0155.fits', 's0176.fits',
#        's0288.fits', 's0270.fits', 's0328.fits', 's0283.fits',
#        's0303.fits', 's0277.fits', 's0306.fits', 's0324.fits',
#        's0289.fits', 's0329.fits', 's0308.fits', 's0350.fits',
#        's0342.fits', 's0330.fits', 's0291.fits', 's0256.fits',
#        's0293.fits', 's0305.fits', 's0282.fits', 's0260.fits',
#        's0274.fits', 's0280.fits', 's0317.fits', 's0336.fits',
#        's0346.fits', 's0292.fits', 's0262.fits', 's0271.fits',
#        's0294.fits', 's0265.fits', 's0266.fits', 's0307.fits',
#        's0325.fits', 's0284.fits', 's0290.fits', 's0318.fits',
#        's0276.fits', 's0344.fits', 's0272.fits', 's0338.fits',
#        's0253.fits', 's0322.fits', 's0299.fits', 's0295.fits',
#        's0304.fits', 's0310.fits', 's0351.fits', 's0278.fits',
#        's0279.fits', 's0348.fits', 's0296.fits', 's0347.fits',
#        's0321.fits', 's0326.fits', 's0287.fits', 's0268.fits',
#        's0300.fits', 's0255.fits', 's0314.fits', 's0285.fits',
#        's0312.fits', 's0264.fits', 's0267.fits', 's0334.fits',
#        's0343.fits', 's0258.fits', 's0335.fits', 's0286.fits',
#        's0331.fits', 's0319.fits', 's0320.fits', 's0269.fits',
#        's0349.fits', 's0340.fits', 's0281.fits', 's0263.fits',
#        's0273.fits', 's0333.fits', 's0323.fits', 's0339.fits',
#        's0297.fits', 's0259.fits', 's0261.fits', 's0302.fits',
#        's0313.fits', 's0315.fits', 's0311.fits', 's0254.fits',
#        's0301.fits', 's0275.fits', 's0252.fits', 's0327.fits',
#        's0337.fits', 's0309.fits', 's0316.fits', 's0257.fits',
#        's0298.fits', 's0341.fits', 's0332.fits', 's0345.fits',
#        's0392.fits', 's0385.fits', 's0415.fits', 's0365.fits',
#        's0378.fits', 's0379.fits', 's0425.fits', 's0408.fits',
#        's0428.fits', 's0359.fits', 's0376.fits', 's0416.fits',
#        's0403.fits', 's0424.fits', 's0401.fits', 's0381.fits',
#        's0422.fits', 's0363.fits', 's0368.fits', 's0417.fits',
#        's0394.fits', 's0371.fits', 's0423.fits', 's0410.fits',
#        's0367.fits', 's0372.fits', 's0352.fits', 's0373.fits',
#        's0364.fits', 's0384.fits', 's0429.fits', 's0369.fits',
#        's0361.fits', 's0386.fits', 's0421.fits', 's0420.fits',
#        's0366.fits', 's0409.fits', 's0389.fits', 's0374.fits',
#        's0419.fits', 's0399.fits', 's0354.fits', 's0427.fits',
#        's0395.fits', 's0353.fits', 's0357.fits', 's0360.fits',
#        's0418.fits', 's0362.fits', 's0387.fits', 's0393.fits',
#        's0400.fits', 's0356.fits', 's0377.fits', 's0390.fits',
#        's0405.fits', 's0380.fits', 's0398.fits', 's0426.fits',
#        's0430.fits', 's0382.fits', 's0355.fits', 's0402.fits',
#        's0370.fits', 's0406.fits', 's0396.fits', 's0407.fits',
#        's0391.fits', 's0413.fits', 's0358.fits', 's0411.fits',
#        's0383.fits', 's0414.fits', 's0388.fits', 's0375.fits',
#        's0404.fits', 's0397.fits', 's0412.fits', 's0433.fits',
#        's0444.fits', 's0497.fits', 's0441.fits', 's0431.fits',
#        's0440.fits', 's0516.fits', 's0477.fits', 's0448.fits',
#        's0472.fits', 's0502.fits', 's0473.fits', 's0487.fits',
#        's0438.fits', 's0510.fits', 's0511.fits', 's0456.fits',
#        's0509.fits', 's0470.fits', 's0463.fits', 's0467.fits',
#        's0445.fits', 's0512.fits', 's0486.fits', 's0468.fits',
#        's0449.fits', 's0491.fits', 's0488.fits', 's0499.fits',
#        's0489.fits', 's0466.fits', 's0443.fits', 's0505.fits',
#        's0458.fits', 's0451.fits', 's0471.fits', 's0521.fits',
#        's0485.fits', 's0452.fits', 's0483.fits', 's0506.fits',
#        's0476.fits', 's0457.fits', 's0490.fits', 's0461.fits',
#        's0517.fits', 's0482.fits', 's0465.fits', 's0515.fits',
#        's0495.fits', 's0518.fits', 's0508.fits', 's0504.fits',
#        's0439.fits', 's0496.fits', 's0437.fits', 's0450.fits',
#        's0446.fits', 's0479.fits', 's0462.fits', 's0493.fits',
#        's0436.fits', 's0469.fits', 's0474.fits', 's0442.fits',
#        's0514.fits', 's0459.fits', 's0455.fits', 's0520.fits',
#        's0432.fits', 's0513.fits', 's0453.fits', 's0484.fits',
#        's0434.fits', 's0460.fits', 's0498.fits', 's0494.fits',
#        's0481.fits', 's0503.fits', 's0478.fits', 's0454.fits',
#        's0500.fits', 's0464.fits', 's0501.fits', 's0492.fits',
#        's0519.fits', 's0507.fits', 's0447.fits', 's0435.fits',
#        's0475.fits', 's0480.fits', 's0574.fits', 's0525.fits',
#        's0553.fits', 's0561.fits', 's0566.fits', 's0527.fits',
#        's0543.fits', 's0588.fits', 's0551.fits', 's0585.fits',
#        's0559.fits', 's0583.fits', 's0580.fits', 's0562.fits',
#        's0569.fits', 's0542.fits', 's0554.fits', 's0575.fits',
#        's0584.fits', 's0533.fits', 's0578.fits', 's0544.fits',
#        's0560.fits', 's0586.fits', 's0563.fits', 's0547.fits',
#        's0539.fits', 's0540.fits', 's0572.fits', 's0545.fits',
#        's0573.fits', 's0529.fits', 's0552.fits', 's0524.fits',
#        's0582.fits', 's0548.fits', 's0565.fits', 's0587.fits',
#        's0549.fits', 's0530.fits', 's0577.fits', 's0531.fits',
#        's0564.fits', 's0532.fits', 's0567.fits', 's0571.fits',
#        's0556.fits', 's0526.fits', 's0523.fits', 's0522.fits',
#        's0579.fits', 's0576.fits', 's0535.fits', 's0541.fits',
#        's0536.fits', 's0555.fits', 's0550.fits', 's0581.fits',
#        's0534.fits', 's0537.fits', 's0538.fits', 's0558.fits',
#        's0546.fits', 's0557.fits', 's0568.fits', 's0570.fits',
#        's0528.fits', 's0606.fits', 's0626.fits', 's0602.fits',
#        's0648.fits', 's0589.fits', 's0654.fits', 's0632.fits',
#        's0673.fits', 's0627.fits', 's0668.fits', 's0608.fits',
#        's0607.fits', 's0613.fits', 's0636.fits', 's0669.fits',
#        's0610.fits', 's0596.fits', 's0631.fits', 's0641.fits',
#        's0666.fits', 's0605.fits', 's0646.fits', 's0670.fits',
#        's0647.fits', 's0645.fits', 's0674.fits', 's0619.fits',
#        's0653.fits', 's0595.fits', 's0621.fits', 's0609.fits',
#        's0604.fits', 's0623.fits', 's0591.fits', 's0672.fits',
#        's0650.fits', 's0598.fits', 's0677.fits', 's0637.fits',
#        's0662.fits', 's0649.fits', 's0643.fits', 's0611.fits',
#        's0661.fits', 's0629.fits', 's0640.fits', 's0625.fits',
#        's0651.fits', 's0663.fits', 's0594.fits', 's0615.fits',
#        's0671.fits', 's0667.fits', 's0597.fits', 's0639.fits',
#        's0656.fits', 's0634.fits', 's0638.fits', 's0675.fits',
#        's0664.fits', 's0614.fits', 's0603.fits', 's0659.fits',
#        's0617.fits', 's0600.fits', 's0599.fits', 's0635.fits',
#        's0628.fits', 's0642.fits', 's0601.fits', 's0652.fits',
#        's0618.fits', 's0644.fits', 's0657.fits', 's0620.fits',
#        's0630.fits', 's0592.fits', 's0622.fits', 's0658.fits',
#        's0665.fits', 's0633.fits', 's0676.fits', 's0660.fits',
#        's0655.fits', 's0616.fits', 's0624.fits', 's0593.fits',
#        's0612.fits', 's0590.fits', 's0705.fits', 's0718.fits',
#        's0717.fits', 's0736.fits', 's0699.fits', 's0691.fits',
#        's0716.fits', 's0742.fits', 's0707.fits', 's0706.fits',
#        's0721.fits', 's0708.fits', 's0689.fits', 's0726.fits',
#        's0722.fits', 's0702.fits', 's0715.fits', 's0739.fits',
#        's0703.fits', 's0697.fits', 's0712.fits', 's0719.fits',
#        's0729.fits', 's0710.fits', 's0724.fits', 's0730.fits',
#        's0737.fits', 's0723.fits', 's0690.fits', 's0714.fits',
#        's0684.fits', 's0720.fits', 's0683.fits', 's0686.fits',
#        's0731.fits', 's0693.fits', 's0725.fits', 's0740.fits',
#        's0696.fits', 's0688.fits', 's0734.fits', 's0687.fits',
#        's0682.fits', 's0741.fits', 's0701.fits', 's0679.fits',
#        's0709.fits', 's0711.fits', 's0680.fits', 's0704.fits',
#        's0694.fits', 's0727.fits', 's0713.fits', 's0692.fits',
#        's0678.fits', 's0698.fits', 's0738.fits', 's0685.fits',
#        's0735.fits', 's0695.fits', 's0728.fits', 's0733.fits',
#        's0732.fits', 's0700.fits', 's0681.fits', 's0749.fits',
#        's0820.fits', 's0807.fits', 's0756.fits', 's0765.fits',
#        's0780.fits', 's0815.fits', 's0800.fits', 's0784.fits',
#        's0790.fits', 's0754.fits', 's0761.fits', 's0804.fits',
#        's0766.fits', 's0806.fits', 's0760.fits', 's0798.fits',
#        's0764.fits', 's0829.fits', 's0830.fits', 's0823.fits',
#        's0771.fits', 's0750.fits', 's0835.fits', 's0802.fits',
#        's0817.fits', 's0822.fits', 's0758.fits', 's0786.fits',
#        's0834.fits', 's0796.fits', 's0778.fits', 's0794.fits',
#        's0814.fits', 's0832.fits', 's0767.fits', 's0755.fits',
#        's0833.fits', 's0762.fits', 's0753.fits', 's0757.fits',
#        's0813.fits', 's0788.fits', 's0819.fits', 's0773.fits',
#        's0744.fits', 's0827.fits', 's0772.fits', 's0811.fits',
#        's0768.fits', 's0789.fits', 's0801.fits', 's0799.fits',
#        's0746.fits', 's0770.fits', 's0745.fits', 's0783.fits',
#        's0797.fits', 's0803.fits', 's0787.fits', 's0824.fits',
#        's0785.fits', 's0751.fits', 's0816.fits', 's0759.fits',
#        's0805.fits', 's0828.fits', 's0763.fits', 's0752.fits',
#        's0782.fits', 's0826.fits', 's0793.fits', 's0775.fits',
#        's0769.fits', 's0810.fits', 's0781.fits', 's0747.fits',
#        's0831.fits', 's0818.fits', 's0779.fits', 's0792.fits',
#        's0795.fits', 's0743.fits', 's0777.fits', 's0825.fits',
#        's0808.fits', 's0776.fits', 's0821.fits', 's0748.fits',
#        's0774.fits', 's0791.fits', 's0812.fits', 's0809.fits',
#        's0925.fits', 's0887.fits', 's0930.fits', 's0894.fits',
#        's0837.fits', 's0854.fits', 's0877.fits', 's0847.fits',
#        's0852.fits', 's0856.fits', 's0931.fits', 's0903.fits',
#        's0879.fits', 's0838.fits', 's0845.fits', 's0924.fits',
#        's0927.fits', 's0851.fits', 's0902.fits', 's0886.fits',
#        's0920.fits', 's0890.fits', 's0881.fits', 's0848.fits',
#        's0905.fits', 's0861.fits', 's0928.fits', 's0841.fits',
#        's0922.fits', 's0878.fits', 's0866.fits', 's0871.fits',
#        's0895.fits', 's0873.fits', 's0855.fits', 's0897.fits',
#        's0867.fits', 's0908.fits', 's0888.fits', 's0913.fits',
#        's0869.fits', 's0914.fits', 's0843.fits', 's0892.fits',
#        's0882.fits', 's0898.fits', 's0850.fits', 's0921.fits',
#        's0909.fits', 's0842.fits', 's0853.fits', 's0839.fits',
#        's0907.fits', 's0893.fits', 's0859.fits', 's0915.fits',
#        's0876.fits', 's0860.fits', 's0865.fits', 's0880.fits',
#        's0836.fits', 's0917.fits', 's0932.fits', 's0883.fits',
#        's0911.fits', 's0840.fits', 's0874.fits', 's0910.fits',
#        's0864.fits', 's0857.fits', 's0934.fits', 's0875.fits',
#        's0900.fits', 's0901.fits', 's0858.fits', 's0926.fits',
#        's0936.fits', 's0863.fits', 's0896.fits', 's0919.fits',
#        's0849.fits', 's0935.fits', 's0872.fits', 's0918.fits',
#        's0916.fits', 's0884.fits', 's0899.fits', 's0923.fits',
#        's0904.fits', 's0889.fits', 's0937.fits', 's0929.fits',
#        's0844.fits', 's0862.fits', 's0870.fits', 's0846.fits',
#        's0933.fits', 's0906.fits', 's0912.fits', 's0868.fits',
#        's0891.fits', 's0885.fits', 's0972.fits', 's0962.fits',
#        's0977.fits', 's0971.fits', 's0967.fits', 's0960.fits',
#        's0978.fits', 's0966.fits', 's0953.fits', 's0975.fits',
#        's0968.fits', 's0947.fits', 's0985.fits', 's0945.fits',
#        's0949.fits', 's0973.fits', 's0951.fits', 's0974.fits',
#        's0942.fits', 's0964.fits', 's0980.fits', 's0983.fits',
#        's0970.fits', 's0940.fits', 's0984.fits', 's0944.fits',
#        's0946.fits', 's0979.fits', 's0954.fits', 's0981.fits',
#        's0955.fits', 's0943.fits', 's0941.fits', 's0982.fits',
#        's0939.fits', 's0976.fits', 's0950.fits', 's0952.fits',
#        's0965.fits', 's0948.fits', 's0963.fits', 's0958.fits',
#        's0961.fits', 's0959.fits', 's0969.fits', 's0957.fits',
#        's0956.fits'], dtype='<U15')

# %%
array["flux_array"]
# Out:
# array([[2.800326  , 2.820038  , 2.8403442 , ..., 0.26744303, 0.2683123 ,
#         0.27005458],
#        [0.20480944, 0.19794364, 0.2035859 , ..., 0.8984447 , 0.88135725,
#         0.87744087],
#        [0.14189121, 0.1389648 , 0.13865823, ..., 0.94967973, 0.93322724,
#         0.93082297],
#        ...,
#        [0.17056978, 0.18025438, 0.17833976, ..., 1.1286676 , 1.1464667 ,
#         1.1668826 ],
#        [0.11795986, 0.17964727, 0.20128004, ..., 1.123267  , 1.1062928 ,
#         1.120373  ],
#        [0.30222747, 0.3139706 , 0.32807022, ..., 0.6965927 , 0.6794233 ,
#         0.6928694 ]], shape=(985, 4306), dtype=float32)
